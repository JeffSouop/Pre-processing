# %% [markdown]
# # Import des modules

# %%
import cv2
import os
import numpy as np

# %% [markdown]
# # Appels des directory

# %%
input_dir = "C:\\Users\\willy\\OneDrive\\Bureau\\images"
output_dir_clear = "C:\\Users\\willy\\OneDrive\\Bureau\\sauvegarde"
output_dir_obstructed = "C:\\Users\\willy\\OneDrive\\Bureau\\corbeille"

# %% [markdown]
# # Fonction d'égalisation

# %%
def brighten_images(img_path):
    # Charger l'image
    img = cv2.imread(img_path)

    # Convertir l'image en niveaux de gris
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Calculer la luminosité moyenne de l'image
    mean_brightness = gray.mean()

    # Si l'image est sombre, augmenter la luminosité
    if mean_brightness < 100:
        alpha = 1.5
        beta = 50
        brightened = cv2.addWeighted(img, alpha, np.zeros(img.shape, img.dtype), 0, beta)

        # Enregistrer l'image modifiée dans le répertoire d'origine
        cv2.imwrite(img_path, brightened)

    else:
        print("L'image n'est pas sombre.")

# %% [markdown]
# # Fonction de detection d'obstruction

# %%
def detect_contours(input_dir, output_dir_clear, output_dir_obstructed):
    # Parcourir toutes les images du dossier d'entrée
    for filename in os.listdir(input_dir):
        # Vérifier si le fichier est une image
        if filename.endswith(".jpg") or filename.endswith(".jpeg") or filename.endswith(".png"):
            # Lire l'image
            image = cv2.imread(os.path.join(input_dir, filename))

            # Convertir l'image en niveaux de gris
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

            # Calculer les contours de l'image
            canny = cv2.Canny(gray, 30, 150)

            # Vérifier si des contours ont été détectés
            if cv2.countNonZero(canny) > 0:
                # Enregistrer l'image détectable dans le dossier correspondant
                cv2.imwrite(os.path.join(output_dir_clear, filename), image)
            else:
                # Enregistrer l'image non détectable dans le dossier correspondant
                cv2.imwrite(os.path.join(output_dir_obstructed, filename), image)

# %% [markdown]
# # Greffe Egalisation & Obstruction

# %%
def brighten_image(img):
    # Convertir l'image en niveaux de gris
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Calculer la luminosité moyenne de l'image
    mean_brightness = gray.mean()

    # Si l'image est sombre, augmenter la luminosité
    if mean_brightness < 100:
        alpha = 1.5
        beta = 50
        brightened = cv2.addWeighted(img, alpha, np.zeros(img.shape, img.dtype), 0, beta)

        return brightened

    else:
        print("L'image n'est pas sombre.")
        return img


def detection_finale(input_dir, output_dir_clear, output_dir_obstructed):
    low_contrast_seuil = 60
    # Parcourir les images dans le dossier d'entrée
    for filename in os.listdir(input_dir):
        # Vérifier que le fichier est une image
        if filename.endswith(".jpg") or filename.endswith(".jpeg") or filename.endswith(".png"):
            # Charger l'image
            image = cv2.imread(os.path.join(input_dir, filename))

            # Augmenter la luminosité de l'image si elle est sombre
            brightened = brighten_image(image)

            # Calculer le contraste de l'image
            gray = cv2.cvtColor(brightened, cv2.COLOR_BGR2GRAY)
            canny = cv2.Canny(gray, 30, 150)
            # contrast = cv2.Laplacian(gray, cv2.CV_64F).var()

